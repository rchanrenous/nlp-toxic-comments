# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x_train = np.load('/content/drive/MyDrive/NLP/bag_of_word/x_train_threshold_100_tf_idf.npy')
y_train = np.load('/content/drive/MyDrive/NLP/bag_of_word/y_train_threshold_100.npy')

# %%
print('x_train : {}'.format(x_train.shape))
print('y_train : {}'.format(y_train.shape))
# Out:
# x_train : (57507, 4239)
# y_train : (57507, 6)

# %%
x_test = np.load('/content/drive/MyDrive/NLP/bag_of_word/x_test_threshold_100_tf_idf.npy')
y_test = np.load('/content/drive/MyDrive/NLP/bag_of_word/y_test_threshold_100.npy')

# %%
# define the model
def buildModel(train_data):

  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(64, input_dim=train_data.shape[1], activation='relu'))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dense(128, activation='relu'))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(0.2))
  model.add(tf.keras.layers.Dense(128, activation='relu'))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(0.2))
  model.add(tf.keras.layers.Dense(6, activation='sigmoid'))

  return model

model = buildModel(x_train)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=tf.keras.metrics.AUC())

# %%
history = model.fit(x_train,y_train, batch_size = 16 ,epochs = 3,validation_split=0.2)
# Out:
# Epoch 1/3
# 2876/2876 [==============================] - 34s 10ms/step - loss: 0.1827 - auc_1: 0.9219 - val_loss: 0.1283 - val_auc_1: 0.9624
# Epoch 2/3
# 2876/2876 [==============================] - 27s 9ms/step - loss: 0.1211 - auc_1: 0.9641 - val_loss: 0.1174 - val_auc_1: 0.9663
# Epoch 3/3
# 2876/2876 [==============================] - 28s 10ms/step - loss: 0.1054 - auc_1: 0.9740 - val_loss: 0.1249 - val_auc_1: 0.9611

# %%
print("Evaluate on test data")
results = model.evaluate(x_test, y_test, batch_size=64)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0809 - auc_1: 0.9659
# test loss, test acc: [0.0808551236987114, 0.9658682942390442]
